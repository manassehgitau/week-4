# %%
import random

# positions (head: Tail)
snakes = {
    99: 78,
    95: 75,
    92: 88,
    64: 60,
    59: 39,
    52: 42,
    36: 6,
    16: 8,
}

ladders = {
    4: 14,
    9: 31,
    21: 42,
    28: 84,
    51: 67,
    72: 91,
    80: 99,
}

players = ["Player 1", "Player 2"]
positions = {player: 0 for player in players}

def roll_dice():
    return random.randint(1, 6)

def move_player(player):
    input(f"{player}, press Enter to roll the dice...")
    roll = roll_dice()
    print(f"{player} rolled a {roll}")
    current = positions[player]
    next_pos = current + roll

    if next_pos > 100:
        print("Roll exceeds 100. Try again next turn.")
        return

    print(f"{player} moves from {current} to {next_pos}")

    # Check for snake or ladder
    if next_pos in snakes:
        print(f"Oh no! A snake bites {player}. Going down from {next_pos} to {snakes[next_pos]}")
        next_pos = snakes[next_pos]
    elif next_pos in ladders:
        print(f"Yay! A ladder lifts {player} up from {next_pos} to {ladders[next_pos]}")
        next_pos = ladders[next_pos]

    positions[player] = next_pos
    print(f"{player} is now at position {positions[player]}")

# Game loop
def play_game():
    while True:
        for player in players:
            move_player(player)
            if positions[player] == 100:
                print(f"\n🎉 {player} wins the game! 🎉")
                return

# Run the game
if __name__ == "__main__":
    print("🎲 Welcome to Snakes and Ladders! 🎲\n")
    play_game()
# Out:
# 🎲 Welcome to Snakes and Ladders! 🎲
#
# Player 1 rolled a 2
# Player 1 moves from 0 to 2
# Player 1 is now at position 2
# Player 2 rolled a 2
# Player 2 moves from 0 to 2
# Player 2 is now at position 2
# Player 1 rolled a 1
# Player 1 moves from 2 to 3
# Player 1 is now at position 3
# Player 2 rolled a 2
# Player 2 moves from 2 to 4
# Yay! A ladder lifts Player 2 up from 4 to 14
# Player 2 is now at position 14
# Player 1 rolled a 6
# Player 1 moves from 3 to 9
# Yay! A ladder lifts Player 1 up from 9 to 31
# Player 1 is now at position 31
# Player 2 rolled a 5
# Player 2 moves from 14 to 19
# Player 2 is now at position 19
# Player 1 rolled a 4
# Player 1 moves from 31 to 35
# Player 1 is now at position 35
# Player 2 rolled a 3
# Player 2 moves from 19 to 22
# Player 2 is now at position 22
# Player 1 rolled a 2
# Player 1 moves from 35 to 37
# Player 1 is now at position 37
# Player 2 rolled a 2
# Player 2 moves from 22 to 24
# Player 2 is now at position 24
# Player 1 rolled a 1
# Player 1 moves from 37 to 38
# Player 1 is now at position 38
# Player 2 rolled a 4
# Player 2 moves from 24 to 28
# Yay! A ladder lifts Player 2 up from 28 to 84
# Player 2 is now at position 84
# Player 1 rolled a 6
# Player 1 moves from 38 to 44
# Player 1 is now at position 44
# Player 2 rolled a 6
# Player 2 moves from 84 to 90
# Player 2 is now at position 90
